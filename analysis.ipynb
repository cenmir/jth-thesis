# %% [markdown]
# # Analysis {#sec-analysis}
#
# *Answer the research questions, one subsection per RQ. Quote the RQ verbatim, then walk through the evidence from the results chapter that supports the answer. The analysis is where the numbers turn into an argument.*

# %% [markdown]
# ## RQ1
#
# *Restate RQ1 here, then answer it using the evidence in @sec-results.*
#
# Template paragraph: RQ1 is answered affirmatively. As shown in @tbl-pid-comparison, the adaptive PID controller reduced the rise time by 26 % and the settling time by 40 %, while halving the overshoot. The improvement holds across all ten runs; the standard deviation of the settling time was 0.04 s for the adaptive controller and 0.09 s for the fixed-gain controller, indicating that the adaptive variant is also more consistent.

# %% [markdown]
# ## RQ2
#
# *Restate RQ2 here, then answer it using the evidence in @sec-results.*
#
# Template paragraph: RQ2 is answered affirmatively. Under the impulse-disturbance test described in @sec-methodology, the fixed-gain controller exceeded the $|\theta| < 5°$ recovery threshold on three of ten runs, while the adaptive controller stayed within threshold on all ten. This supports the claim that the adaptive variant rejects disturbances more reliably.
#
# If an RQ cannot be answered, say so explicitly and explain why. "Inconclusive" is a valid result; "unanswered" is not.
